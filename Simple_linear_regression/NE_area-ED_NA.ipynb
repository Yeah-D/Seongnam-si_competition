# %%
# 단순선형회귀분석

import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

df = pd.read_csv('Elderly_Accident_Dataset.csv')

# %%
# NE_area 와 ED_NA_2019 간의 회귀분석 및 산점도 시각화
X = df.NE_area.values
Y = df.ED_NA_2019.values

# 독립 변수 X에 상수항 추가
X = sm.add_constant(X)

# 선형 회귀 모델 적합
model = sm.OLS(Y, X)
result = model.fit()

# 회귀 분석 결과 출력
print(result.summary())

# 산점도와 회귀선 그리기
plt.scatter(X[:, 1], Y, alpha=0.5, c=['red' if x == 0.00094632049 else 'blue' for x in df.NE_area])
plt.plot(X[:, 1], result.predict(), color='r')

# 그래프 축 라벨링 및 타이틀 추가
plt.xlabel('NE_area')
plt.ylabel('ED_NA_2019')
plt.title('Linear Regression')

# 그래프 출력
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     2.592
# Date:                Thu, 25 May 2023   Prob (F-statistic):              0.112
# Time:                        16:40:37   Log-Likelihood:                -408.05
# No. Observations:                  66   AIC:                             820.1
# Df Residuals:                      64   BIC:                             824.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        175.5336     22.094      7.945      0.000     131.395     219.672
# ...

# %%
# NE_area 와 ED_NA_2020 간의 회귀분석 및 산점도 시각화
X = df.NE_area.values
Y = df.ED_NA_2020.values

# 독립 변수 X에 상수항 추가
X = sm.add_constant(X)

# 선형 회귀 모델 적합
model = sm.OLS(Y, X)
result = model.fit()

# 회귀 분석 결과 출력
print(result.summary())

# 산점도와 회귀선 그리기
plt.scatter(X[:, 1], Y, alpha=0.5, c=['red' if x == 0.00094632049 else 'blue' for x in df.NE_area])
plt.plot(X[:, 1], result.predict(), color='r')

# 그래프 축 라벨링 및 타이틀 추가
plt.xlabel('NE_area')
plt.ylabel('ED_NA_2020')
plt.title('Linear Regression')

# 그래프 출력
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.339
# Date:                Thu, 25 May 2023   Prob (F-statistic):              0.252
# Time:                        16:42:18   Log-Likelihood:                -405.12
# No. Observations:                  66   AIC:                             814.2
# Df Residuals:                      64   BIC:                             818.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        171.6606     21.136      8.122      0.000     129.436     213.885
# ...

# %%
# NE_area 와 ED_NA_2021 간의 회귀분석 및 산점도 시각화
X = df.NE_area.values
Y = df.ED_NA_2021.values

# 독립 변수 X에 상수항 추가
X = sm.add_constant(X)

# 선형 회귀 모델 적합
model = sm.OLS(Y, X)
result = model.fit()

# 회귀 분석 결과 출력
print(result.summary())

# 산점도와 회귀선 그리기
plt.scatter(X[:, 1], Y, alpha=0.5, c=['red' if x == 0.00094632049 else 'blue' for x in df.NE_area])
plt.plot(X[:, 1], result.predict(), color='r')

# 그래프 축 라벨링 및 타이틀 추가
plt.xlabel('NE_area')
plt.ylabel('ED_NA_2021')
plt.title('Linear Regression')

# 그래프 출력
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.5108
# Date:                Thu, 25 May 2023   Prob (F-statistic):              0.477
# Time:                        16:42:40   Log-Likelihood:                -414.41
# No. Observations:                  66   AIC:                             832.8
# Df Residuals:                      64   BIC:                             837.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        187.1473     24.330      7.692      0.000     138.543     235.752
# ...

# %%
# NE_area 와 ED_NA_2022 간의 회귀분석 및 산점도 시각화
X = df.NE_area.values
Y = df.ED_NA_2022.values

# 독립 변수 X에 상수항 추가
X = sm.add_constant(X)

# 선형 회귀 모델 적합
model = sm.OLS(Y, X)
result = model.fit()

# 회귀 분석 결과 출력
print(result.summary())

# 산점도와 회귀선 그리기
plt.scatter(X[:, 1], Y, alpha=0.5, c=['red' if x == 0.00094632049 else 'blue' for x in df.NE_area])
plt.plot(X[:, 1], result.predict(), color='r')

# 그래프 축 라벨링 및 타이틀 추가
plt.xlabel('NE_area')
plt.ylabel('ED_NA_2022')
plt.title('Linear Regression')

# 그래프 출력
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.3129
# Date:                Thu, 25 May 2023   Prob (F-statistic):              0.578
# Time:                        16:43:01   Log-Likelihood:                -420.97
# No. Observations:                  66   AIC:                             845.9
# Df Residuals:                      64   BIC:                             850.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        216.1394     26.872      8.043      0.000     162.457     269.822
# ...
